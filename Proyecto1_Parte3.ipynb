# %%
#Como parte inicial, descargamos la informacion y la cargamos en nuestro cuader en Colab
import pandas as pd
filename = "/content/sales_predictions.csv"
df = pd.read_csv(filename)

# %%
# A continuacion revisaremos aquellos datos nulos para ver la integridad de la informacion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Revisaremos los primero diez datos para dimensionar la magnitud de la info
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
# Revisaremos la estadistica descriptiva
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# A continuacion revisaremos la columna Item_Weight, donde entendemos que existe un peso unico para cada producto, por lo que la informacion nula, puede ser reemplazada en bada a la columna Item_Identifier
df2=df.groupby(['Item_Identifier'])[['Item_Weight']].mean()
df2
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1559 rows x 1 columns]

# %%
# A traves se un simple ejemplo podemos visualizar que para un mismo codigo existe un unico peso, sin embargo varios tamaños, por lo que solo sera posible gestionar (reemplazar) la variable peso y tener que lidiar con los datos nulos que aparecen en la comuna tamaño, de igual forma no considero que esta ultima tenga un peso tan relevante en termino de decisiones.
df4=df
itemfilter= df4["Item_Identifier"]== "FDP10"
df4=df4.loc[itemfilter,:]
df4
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 585            FDP10         19.0          Low Fat         0.128066
# 2623           FDP10         19.0          Low Fat         0.128815
# 3382           FDP10         19.0          Low Fat         0.128289
# 4585           FDP10         19.0          Low Fat         0.128090
# 6087           FDP10         19.0          Low Fat         0.128350
# 7883           FDP10         19.0          Low Fat         0.127984
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7     Snack Foods  107.7622            OUT027                       1985
# 585   Snack Foods  104.3622            OUT035                       2004
# 2623  Snack Foods  107.6622            OUT017                       2007
# 3382  Snack Foods  104.9622            OUT049                       1999
# ...

# %%
df3=df
byweight = df3.sort_values("Item_Weight")
byweight.head(10)
# A continuacion podemos corroborar que para cada codigo existe un unico peso, por lo que podemos asignar un peso para los valores nulos, en la medida que su peso se encuentre asignado en el resto del DF.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7808           FDP40        4.555          Regular         0.034329
# 4430           FDP40        4.555          Regular         0.034357
# 3489           FDP40        4.555          Regular         0.034351
# 4400           FDP40        4.555          Regular         0.034411
# 3077           DRE12        4.590          Low Fat         0.070767
# 7984           DRE12        4.590          Low Fat         0.000000
# 6432           DRE12        4.590          Low Fat         0.070722
# 1515           DRE12        4.590          Low Fat         0.070781
# 1082           DRE12        4.590          Low Fat         0.070891
# 5493           DRF23        4.610          Low Fat         0.000000
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7808  Frozen Foods  110.1544            OUT013                       1987
# ...

# %%
# Aca podemos confirmar algunos valores nulos
byweight.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8458           FDX20          NaN          Low Fat         0.074518
# 8463           FDG59          NaN          Low Fat         0.043025
# 8469           FDQ45          NaN          Regular         0.019114
# 8472           NCS41          NaN          Low Fat         0.053185
# 8480           FDQ58          NaN          Low Fat         0.000000
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 8458  Fruits and Vegetables  227.3720            OUT019
# 8463          Starchy Foods   37.6164            OUT027
# ...

# %%
# A traves de la siguiente funcion logramos reemplazar todos los valores nulos asociados a las columna peso, para todos los Items que ya tenian un peso asignado. 
def Upgrade_Item_Identifier_mean(Item_Identifier):
  Item_Identifier_filter  = df['Item_Identifier'] == Item_Identifier
  values_mean = df[Item_Identifier_filter]['Item_Weight'].mean()
  return values_mean


Item_Weight_filter_isna = df['Item_Weight'].isna()

df.loc[Item_Weight_filter_isna , 'Item_Weight'] = df.apply(lambda x:Upgrade_Item_Identifier_mean( x['Item_Identifier']) ,axis=1 )
df[Item_Weight_filter_isna]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10       19.000          Low Fat         0.127470
# 18             DRI11        8.260          Low Fat         0.034238
# 21             FDW12        8.315          Regular         0.035400
# 23             FDC37       15.500          Low Fat         0.057557
# 29             FDC14       14.500          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37        5.000          Low Fat         0.043792
# 8487           DRG13       17.250          Low Fat         0.037006
# 8488           NCN14       19.100          Low Fat         0.091473
# 8490           FDU44       12.150          Regular         0.102296
# 8504           NCN18        8.895          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8519 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# En base a la definicion de las principales variables de nuestro dataframe, avanzaremos con procesos de visualizacion de las siguientes variables:
# Item_Visibility / Outlet_Location_Type

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a9af3_row0_col0, #T_a9af3_row1_col1, #T_a9af3_row2_col2, #T_a9af3_row3_col3, #T_a9af3_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a9af3_row0_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_a9af3_row0_col2, #T_a9af3_row4_col0, #T_a9af3_row4_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a9af3_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a9af3_row0_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a9af3_row1_col0, #T_a9af3_row3_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a9af3_row1_col2, #T_a9af3_row1_col3, #T_a9af3_row1_col4, #T_a9af3_row3_col0, #T_a9af3_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a9af3_row2_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a9af3_row2_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_a9af3_row2_col3 {
# ...

# %%
df2=df.groupby(['Item_Type'])[['Item_Outlet_Sales']].sum().reset_index().sort_values(by="Item_Outlet_Sales",ascending=False)

import matplotlib.pyplot as plt
from numpy import arange
from numpy.random import randint

fig1 = plt.figure(dpi=100)
ax1 = fig1.add_subplot(111)
sep = 0.3

#barras - parametro 1: valores de x; parametro 2: valores en y; parametro 3: ancho de barra.
#print(x, ya, yb)
ax1.bar(df2["Item_Type"],df2["Item_Outlet_Sales"], sep, color='lightblue')
#ax1.plot(x, ya, 'gD--', color='green')
#ax1.set_xticks(x+sep) #posición de etiquetas en x

plt.xticks(rotation=90)

#ax1.set_xticklabels(["c1","c2","c3","c4","c5","c6","c7","c8","c9","c10"]) #nombre de etiquetas en x

plt.show()

# %%
import matplotlib.pyplot as plt

fig1 = plt.figure(dpi=120)
ax1 = fig1.add_subplot(1,1,1) 

# explotar = [0, 0, 0.1, 0] #sirve para destacar alguna porcion. El valor es cuanto se separa de la torta.


# %.2f%% formato de decimal, viene del lenguaje C. Sí, python está escrito en C.

ax1.pie(df2["Item_Outlet_Sales"], autopct="%.2f%%", shadow = False, startangle=-90)

ax1.legend(bbox_to_anchor=(1, 1.02), loc='upper left', labels= df2["Item_Type"])

ax1.axis("equal") #asegura proporcion igualitaria, vale decir, suma de porcentajes 100% (círculo)

plt.show()

# %%
df3=df.groupby(['Item_Type'])[['Item_MRP']].mean().reset_index().sort_values(by="Item_MRP",ascending=False)
df3

import matplotlib.pyplot as plt
from numpy import arange
from numpy.random import randint

fig1 = plt.figure(dpi=100)
ax1 = fig1.add_subplot(111)
sep = 0.3

#barras - parametro 1: valores de x; parametro 2: valores en y; parametro 3: ancho de barra.
#print(x, ya, yb)
ax1.bar(df3["Item_Type"],df3["Item_MRP"], sep, color='lightblue')
#ax1.plot(x, ya, 'gD--', color='green')
#ax1.set_xticks(x+sep) #posición de etiquetas en x

plt.xticks(rotation=90)

#ax1.set_xticklabels(["c1","c2","c3","c4","c5","c6","c7","c8","c9","c10"]) #nombre de etiquetas en x

plt.show()

# %%
df4=df.groupby(['Outlet_Type'])[['Item_Outlet_Sales']].sum().reset_index().sort_values(by="Outlet_Type",ascending=False)
import matplotlib.pyplot as plt

fig1 = plt.figure(dpi=120)
ax1 = fig1.add_subplot(1,1,1) 

# explotar = [0, 0, 0.1, 0] #sirve para destacar alguna porcion. El valor es cuanto se separa de la torta.


# %.2f%% formato de decimal, viene del lenguaje C. Sí, python está escrito en C.

ax1.pie(df4["Item_Outlet_Sales"], autopct="%.2f%%", shadow = False, startangle=-90)

ax1.legend(bbox_to_anchor=(1, 1.02), loc='upper left', labels= df4["Outlet_Type"])

ax1.axis("equal") #asegura proporcion igualitaria, vale decir, suma de porcentajes 100% (círculo)

plt.show()

# %%
df5=df.groupby(['Outlet_Establishment_Year'])[['Item_Outlet_Sales']].sum().reset_index().sort_values(by="Outlet_Establishment_Year",ascending=False)
df5

import matplotlib.pyplot as plt
from numpy import arange
from numpy.random import randint

fig1 = plt.figure(dpi=100)
ax1 = fig1.add_subplot(111)
sep = 0.3

#barras - parametro 1: valores de x; parametro 2: valores en y; parametro 3: ancho de barra.
#print(x, ya, yb)
ax1.bar(df5["Outlet_Establishment_Year"],df5["Item_Outlet_Sales"], sep, color='lightblue')
#ax1.plot(x, ya, 'gD--', color='green')
#ax1.set_xticks(x+sep) #posición de etiquetas en x

plt.xticks(rotation=90)

#ax1.set_xticklabels(["c1","c2","c3","c4","c5","c6","c7","c8","c9","c10"]) #nombre de etiquetas en x

plt.show()

# %%
df6=df
from matplotlib import pyplot as plt
import seaborn as sns

fig = plt.figure(dpi=100)
fig.suptitle("Relacion entre Nivel de Visibilidad y Venta", fontsize=14, fontweight="bold")

ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85) 

ax.set_title("Visibilidad vs Venta")
ax.set_xlabel("Visibilidad")
ax.set_ylabel("Ventas")

ax.plot(df6["Item_Visibility"], df6["Item_Outlet_Sales"], '.')

plt.show()
